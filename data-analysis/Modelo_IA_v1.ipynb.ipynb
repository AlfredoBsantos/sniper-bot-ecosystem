# %%
# Instala as bibliotecas necessárias para a sessão
# !pip install pandas sqlalchemy psycopg2-binary web3 tqdm scikit-learn matplotlib seaborn

# Importa as ferramentas
import pandas as pd
from sqlalchemy import create_engine
import json
from web3 import Web3
from tqdm.auto import tqdm

print("--- Passo 1: Carregando Dados da Mainnet ---")
# Conecta ao banco de dados
db_connection_str = 'postgresql://admin:supersecret@localhost:5433/mempool_data'
db_engine = create_engine(db_connection_str)

try:
    df_raw = pd.read_sql("SELECT * FROM transactions", con=db_engine)
    print(f"Sucesso! Carregamos {len(df_raw)} transações REAIS e enriquecidas.")
    # Remove qualquer linha que possa ter falhado na coleta
    df_raw.dropna(subset=['inputData', 'base_fee_per_gas'], inplace=True)
    df_raw = df_raw[df_raw['inputData'] != '0x'] # Remove transações sem input data
    print(f"Temos {len(df_raw)} transações válidas para análise.")
    
except Exception as e:
    print(f"--- ERRO ao carregar dados do banco: {e} ---")
    df = pd.DataFrame()
# Out:
# Requirement already satisfied: pandas in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (2.2.3)
# Requirement already satisfied: sqlalchemy in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (2.0.39)
# Requirement already satisfied: psycopg2-binary in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (2.9.10)
# Requirement already satisfied: web3 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (7.12.0)
# Requirement already satisfied: tqdm in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (4.67.1)
# Requirement already satisfied: scikit-learn in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (1.7.0)
# Requirement already satisfied: matplotlib in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (3.10.3)
# Requirement already satisfied: seaborn in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from pandas) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from sqlalchemy) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from sqlalchemy) (4.12.2)
# Requirement already satisfied: eth-abi>=5.0.1 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from web3) (5.2.0)
# Requirement already satisfied: eth-account>=0.13.6 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from web3) (0.13.7)
# Requirement already satisfied: eth-hash>=0.5.1 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from eth-hash[pycryptodome]>=0.5.1->web3) (0.7.1)
# Requirement already satisfied: eth-typing>=5.0.0 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from web3) (5.2.1)
# Requirement already satisfied: eth-utils>=5.0.0 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from web3) (5.3.0)
# Requirement already satisfied: hexbytes>=1.2.0 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from web3) (1.3.1)
# Requirement already satisfied: aiohttp>=3.7.4.post0 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from web3) (3.12.13)
# Requirement already satisfied: pydantic>=2.4.0 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from web3) (2.11.7)
# Requirement already satisfied: pywin32>=223 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from web3) (308)
# Requirement already satisfied: requests>=2.23.0 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from web3) (2.32.3)
# Requirement already satisfied: types-requests>=2.0.0 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from web3) (2.32.4.20250611)
# Requirement already satisfied: websockets<16.0.0,>=10.0.0 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from web3) (15.0.1)
# Requirement already satisfied: pyunormalize>=15.0.0 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from web3) (16.0.0)
# Requirement already satisfied: colorama in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from aiohttp>=3.7.4.post0->web3) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from aiohttp>=3.7.4.post0->web3) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from aiohttp>=3.7.4.post0->web3) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from aiohttp>=3.7.4.post0->web3) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from aiohttp>=3.7.4.post0->web3) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from aiohttp>=3.7.4.post0->web3) (6.5.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from aiohttp>=3.7.4.post0->web3) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from aiohttp>=3.7.4.post0->web3) (1.20.1)
# Requirement already satisfied: idna>=2.0 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp>=3.7.4.post0->web3) (3.7)
# Requirement already satisfied: parsimonious<0.11.0,>=0.10.0 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from eth-abi>=5.0.1->web3) (0.10.0)
# Requirement already satisfied: regex>=2022.3.15 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from parsimonious<0.11.0,>=0.10.0->eth-abi>=5.0.1->web3) (2024.11.6)
# Requirement already satisfied: bitarray>=2.4.0 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from eth-account>=0.13.6->web3) (3.4.2)
# Requirement already satisfied: eth-keyfile<0.9.0,>=0.7.0 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from eth-account>=0.13.6->web3) (0.8.1)
# Requirement already satisfied: eth-keys>=0.4.0 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from eth-account>=0.13.6->web3) (0.7.0)
# Requirement already satisfied: eth-rlp>=2.1.0 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from eth-account>=0.13.6->web3) (2.2.0)
# Requirement already satisfied: rlp>=1.0.0 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from eth-account>=0.13.6->web3) (4.1.0)
# Requirement already satisfied: ckzg>=2.0.0 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from eth-account>=0.13.6->web3) (2.1.1)
# Requirement already satisfied: pycryptodome<4,>=3.6.6 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from eth-keyfile<0.9.0,>=0.7.0->eth-account>=0.13.6->web3) (3.23.0)
# Requirement already satisfied: cytoolz>=0.10.1 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from eth-utils>=5.0.0->web3) (1.0.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from pydantic>=2.4.0->web3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from pydantic>=2.4.0->web3) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from pydantic>=2.4.0->web3) (0.4.1)
# Requirement already satisfied: toolz>=0.8.0 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from cytoolz>=0.10.1->eth-utils>=5.0.0->web3) (1.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from requests>=2.23.0->web3) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from requests>=2.23.0->web3) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alfre\anaconda3\envs\sniper_env\lib\site-packages (from requests>=2.23.0->web3) (2025.4.26)
# --- Passo 1: Carregando Dados da Mainnet ---
# Sucesso! Carregamos 24014 transações REAIS e enriquecidas.
# Temos 24013 transações válidas para análise.

# %%
if not df_raw.empty:
    print("\n--- Passo 2: Decodificando transações e criando features ---")
    
    # ABI para decodificar swaps da Uniswap V2
    router_v2_abi_str = '[{"inputs":[{"type":"uint256","name":"amountIn"},{"type":"uint256","name":"amountOutMin"},{"type":"address[]","name":"path"}],"name":"swapExactTokensForTokens","type":"function"},{"inputs":[{"type":"uint256","name":"amountOutMin"},{"type":"address[]","name":"path"}],"name":"swapExactETHForTokens","type":"function"}]'
    router_abi = json.loads(router_v2_abi_str)
    generic_contract = Web3().eth.contract(abi=router_abi)

    def decode_input_data(input_data):
        try:
            input_bytes = bytes.fromhex(input_data[2:])
            func_obj, func_params = generic_contract.decode_function_input(input_bytes)
            # Retorna o nome da função e os parâmetros como um dicionário
            return pd.Series([func_obj.fn_name, func_params])
        except Exception:
            return pd.Series(['desconhecido', {}])

    # Cria as novas colunas
    df_raw[['function_name', 'params']] = df_raw['inputData'].apply(decode_input_data)
    
    # Filtra apenas os swaps diretos de token para token
    swaps_df = df_raw[df_raw['function_name'] == 'swapExactTokensForTokens'].copy()
    
    # Cria as features que usaremos para treinar o modelo
    if not swaps_df.empty:
        swaps_df['token_in'] = swaps_df['params'].apply(lambda p: p.get('path', [None])[0])
        swaps_df['token_out'] = swaps_df['params'].apply(lambda p: p.get('path', [None])[-1])
        swaps_df['amount_in'] = swaps_df['params'].apply(lambda p: p.get('amountIn', 0))
        # Limpando colunas numéricas que vieram como texto
        swaps_df['gas_price_numeric'] = pd.to_numeric(swaps_df['gas_price'], errors='coerce').fillna(0)
        swaps_df['base_fee_numeric'] = pd.to_numeric(swaps_df['base_fee_per_gas'], errors='coerce').fillna(0)
        swaps_df['value_numeric'] = pd.to_numeric(swaps_df['value'], errors='coerce').fillna(0)
        
        # FEATURE NOVA: Gorjeta do Minerador (sinal de urgência)
        swaps_df['priority_fee'] = swaps_df['gas_price_numeric'] - swaps_df['base_fee_numeric']
        
        print(f"Engenharia de features concluída! Encontramos {len(swaps_df)} swaps para usar.")
        display(swaps_df[['hash', 'token_in', 'token_out', 'amount_in', 'priority_fee']].head())
    else:
        print("Nenhum swap do tipo 'swapExactTokensForTokens' encontrado na amostra.")

else:
    print("DataFrame original vazio. Verifique a Célula 1.")
# Out:
# --- Passo 2: Decodificando transações e criando features ---
# Nenhum swap do tipo 'swapExactTokensForTokens' encontrado na amostra.

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# Só executa se tivermos swaps para analisar
if not swaps_df.empty:
    print("\n--- Passo 3: Rotulando dados e treinando o modelo de IA ---")
    # A lógica de cálculo de preço (getAmountOut) é complexa de replicar aqui.
    # Para este exercício final, vamos criar um "alvo" baseado em uma heurística forte:
    # "Uma oportunidade de arbitragem é mais provável em uma transação com gorjeta alta e valor alto"
    
    # Criando um alvo proxy (substituto) para o treinamento
    amount_in_threshold = swaps_df['amount_in'].quantile(0.90) # Top 10% dos valores
    priority_fee_threshold = swaps_df['priority_fee'].quantile(0.90) # Top 10% das gorjetas
    
    swaps_df['arbitrage_opportunity'] = ((swaps_df['amount_in'] > amount_in_threshold) & (swaps_df['priority_fee'] > priority_fee_threshold)).astype(int)
    
    print("Distribuição do nosso alvo 'arbitrage_opportunity':")
    print(swaps_df['arbitrage_opportunity'].value_counts())

    # --- Treinamento da IA ---
    # Features que usaremos: valor do swap, limite de gás, e a gorjeta paga
    features = ['amount_in', 'gas_limit', 'priority_fee']
    X = swaps_df[features]
    y = swaps_df['arbitrage_opportunity']
    
    if len(swaps_df[y==1]) > 1: # Garante que temos pelo menos uma oportunidade para treinar
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

        model = RandomForestClassifier(n_estimators=100, random_state=42, max_depth=10)
        print("\nTreinando o modelo de IA v1.0...")
        model.fit(X_train, y_train)
        print("Treinamento concluído!")
        
        predictions = model.predict(X_test)
        accuracy = accuracy_score(y_test, predictions)
        
        print("\n--- AVALIAÇÃO DO MODELO FINAL ---")
        print(f"Acurácia: {accuracy * 100:.2f}%")
        print("\nRelatório de Classificação:")
        print(classification_report(y_test, predictions))
    else:
        print("\nNão foram encontradas 'oportunidades' suficientes no dataset para treinar o modelo.")

else:
    print("Nenhum swap encontrado para analisar. Deixe o coletor rodar mais.")
# Out:
# Nenhum swap encontrado para analisar. Deixe o coletor rodar mais.
